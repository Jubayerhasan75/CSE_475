# %% [markdown]
# # 1. Environment Setup and Library Imports

# %%
# !pip install thop -q

import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from thop import profile
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, roc_auc_score, roc_curve

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
classes = ['AD', 'CN', 'MCI']
label_map = {cls: i for i, cls in enumerate(classes)}

# %% [markdown]
# # 2. Dataset Loading and Stratified Splitting (10:90 Ratio)

# %%
base_path = '/kaggle/input/datasets/jubayerhasan755/notebook1-dataset/alzheimer'
all_paths = []
all_labels = []

for split_folder in ['train', 'test']:
    for cls in classes:
        folder_path = os.path.join(base_path, split_folder, cls)
        if os.path.exists(folder_path):
            for img in os.listdir(folder_path):
                if img.lower().endswith(('.png', '.jpg', '.jpeg')):
                    all_paths.append(os.path.join(folder_path, img))
                    all_labels.append(label_map[cls])

train_files, test_files, train_labels, test_labels = train_test_split(
    all_paths, all_labels, train_size=0.1, stratify=all_labels, random_state=42
)

t_files, v_files, t_labels, v_labels = train_test_split(
    train_files, train_labels, test_size=0.1, stratify=train_labels, random_state=42
)

class AlzheimerDataset(Dataset):
    def __init__(self, paths, labels, transform=None):
        self.paths = paths
        self.labels = labels
        self.transform = transform
    def __len__(self):
        return len(self.paths)
    def __getitem__(self, idx):
        img = Image.open(self.paths[idx]).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, self.labels[idx]

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_loader = DataLoader(AlzheimerDataset(t_files, t_labels, transform), batch_size=32, shuffle=True)
val_loader = DataLoader(AlzheimerDataset(v_files, v_labels, transform), batch_size=32)
test_loader = DataLoader(AlzheimerDataset(test_files, test_labels, transform), batch_size=32)

print(f"Total Images: {len(all_paths)}")
print(f"Training (10%): {len(t_files)}, Validation: {len(v_files)}, Testing (90%): {len(test_files)}")
# Out:
# Total Images: 5154
# Training (10%): 463, Validation: 52, Testing (90%): 4639

# %% [markdown]
# # 3. Computational Complexity: GFLOPs per Inference (Input Size: 224x224)

# %%
model = models.resnet50(weights='IMAGENET1K_V1')
model.fc = nn.Linear(model.fc.in_features, len(classes))
model = model.to(device)

dummy_in = torch.randn(1, 3, 224, 224).to(device)
macs, params = profile(model, inputs=(dummy_in, ), verbose=False)
gflops = (macs * 2) / 1e9

print(f"Fixed Input Size: 224x224")
print(f"GFLOPs: {gflops:.4f}")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 136MB/s]
# Fixed Input Size: 224x224
# GFLOPs: 8.2634

# %% [markdown]
# # 4. Model Training and Training Wall-clock Time Tracking

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

start_train = time.time()
for epoch in range(50):
    model.train()
    running_loss = 0.0
    for imgs, labs in train_loader:
        imgs, labs = imgs.to(device), labs.to(device)
        optimizer.zero_grad()
        loss = criterion(model(imgs), labs)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for imgs, labs in val_loader:
            imgs, labs = imgs.to(device), labs.to(device)
            val_loss += criterion(model(imgs), labs).item()
    
    print(f"Epoch [{epoch+1}/50] | Train Loss: {running_loss/len(train_loader):.4f} | Val Loss: {val_loss/len(val_loader):.4f}")

train_wall_time = time.time() - start_train
print(f"Total Training Time: {train_wall_time:.2f} s")
# Out:
# Epoch [1/50] | Train Loss: 0.9569 | Val Loss: 0.9018
# Epoch [2/50] | Train Loss: 0.2538 | Val Loss: 0.5689
# Epoch [3/50] | Train Loss: 0.0426 | Val Loss: 0.2352
# Epoch [4/50] | Train Loss: 0.0161 | Val Loss: 0.2534
# Epoch [5/50] | Train Loss: 0.0140 | Val Loss: 0.3020
# Epoch [6/50] | Train Loss: 0.0122 | Val Loss: 0.3460
# Epoch [7/50] | Train Loss: 0.0089 | Val Loss: 0.4485
# Epoch [8/50] | Train Loss: 0.0139 | Val Loss: 0.2102
# Epoch [9/50] | Train Loss: 0.0793 | Val Loss: 0.9898
# Epoch [10/50] | Train Loss: 0.1786 | Val Loss: 0.3868
# Epoch [11/50] | Train Loss: 0.1099 | Val Loss: 0.7766
# Epoch [12/50] | Train Loss: 0.0789 | Val Loss: 0.2522
# Epoch [13/50] | Train Loss: 0.0407 | Val Loss: 0.2116
# Epoch [14/50] | Train Loss: 0.0238 | Val Loss: 0.1749
# Epoch [15/50] | Train Loss: 0.0054 | Val Loss: 0.0838
# Epoch [16/50] | Train Loss: 0.0075 | Val Loss: 0.1092
# Epoch [17/50] | Train Loss: 0.0053 | Val Loss: 0.1026
# Epoch [18/50] | Train Loss: 0.0029 | Val Loss: 0.1866
# Epoch [19/50] | Train Loss: 0.0017 | Val Loss: 0.1917
# Epoch [20/50] | Train Loss: 0.0038 | Val Loss: 0.1337
# Epoch [21/50] | Train Loss: 0.0009 | Val Loss: 0.1157
# Epoch [22/50] | Train Loss: 0.0023 | Val Loss: 0.1103
# Epoch [23/50] | Train Loss: 0.0028 | Val Loss: 0.1131
# Epoch [24/50] | Train Loss: 0.0073 | Val Loss: 0.1182
# Epoch [25/50] | Train Loss: 0.0059 | Val Loss: 0.3264
# Epoch [26/50] | Train Loss: 0.0100 | Val Loss: 0.1821
# Epoch [27/50] | Train Loss: 0.0131 | Val Loss: 0.2463
# Epoch [28/50] | Train Loss: 0.0145 | Val Loss: 0.2216
# Epoch [29/50] | Train Loss: 0.0143 | Val Loss: 0.1832
# Epoch [30/50] | Train Loss: 0.0075 | Val Loss: 0.0876
# Epoch [31/50] | Train Loss: 0.0085 | Val Loss: 0.1916
# Epoch [32/50] | Train Loss: 0.0309 | Val Loss: 0.3086
# Epoch [33/50] | Train Loss: 0.0560 | Val Loss: 0.4398
# Epoch [34/50] | Train Loss: 0.0469 | Val Loss: 0.1741
# Epoch [35/50] | Train Loss: 0.0524 | Val Loss: 0.1797
# Epoch [36/50] | Train Loss: 0.0907 | Val Loss: 0.2861
# Epoch [37/50] | Train Loss: 0.1238 | Val Loss: 0.1989
# Epoch [38/50] | Train Loss: 0.0311 | Val Loss: 0.7630
# Epoch [39/50] | Train Loss: 0.0122 | Val Loss: 0.7759
# Epoch [40/50] | Train Loss: 0.0168 | Val Loss: 0.4244
# Epoch [41/50] | Train Loss: 0.0171 | Val Loss: 0.1076
# Epoch [42/50] | Train Loss: 0.0093 | Val Loss: 0.1166
# Epoch [43/50] | Train Loss: 0.0030 | Val Loss: 0.1662
# Epoch [44/50] | Train Loss: 0.0022 | Val Loss: 0.1949
# Epoch [45/50] | Train Loss: 0.0031 | Val Loss: 0.2352
# Epoch [46/50] | Train Loss: 0.0011 | Val Loss: 0.2938
# Epoch [47/50] | Train Loss: 0.0013 | Val Loss: 0.2571
# Epoch [48/50] | Train Loss: 0.0014 | Val Loss: 0.2002
# Epoch [49/50] | Train Loss: 0.0008 | Val Loss: 0.1945
# Epoch [50/50] | Train Loss: 0.0003 | Val Loss: 0.1907
# Total Training Time: 299.50 s

# %% [markdown]
# # 5. Global Performance Metrics and Testing Wall-clock Time

# %%
model.eval()
y_true, y_pred, y_prob = [], [], []
start_test = time.time()
with torch.no_grad():
    for imgs, labs in test_loader:
        imgs, labs = imgs.to(device), labs.to(device)
        out = model(imgs)
        y_prob.extend(torch.softmax(out, dim=1).cpu().numpy())
        y_pred.extend(torch.argmax(out, dim=1).cpu().numpy())
        y_true.extend(labs.cpu().numpy())
test_wall_time = time.time() - start_test

acc = accuracy_score(y_true, y_pred)
p, r, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')
auc = roc_auc_score(y_true, y_prob, multi_class='ovr')

print(f"Accuracy: {acc:.4f}")
print(f"Precision: {p:.4f}")
print(f"Recall: {r:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"ROC-AUC: {auc:.4f}")
print(f"Testing Wall-clock Time: {test_wall_time:.2f} s")
# Out:
# Accuracy: 0.8840
# Precision: 0.8852
# Recall: 0.8840
# F1-score: 0.8829
# ROC-AUC: 0.9732
# Testing Wall-clock Time: 40.30 s

# %% [markdown]
# # 6. Per-class Accuracy and Confusion Matrix Analysis

# %%
cm = confusion_matrix(y_true, y_pred)
per_class_acc = cm.diagonal() / cm.sum(axis=1)

for i, cls in enumerate(classes):
    print(f"Accuracy for {cls}: {per_class_acc[i]:.4f}")

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix (10:90 Split)')
plt.show()
# Out:
# Accuracy for AD: 0.7826
# Accuracy for CN: 0.8557
# Accuracy for MCI: 0.9438

# %% [markdown]
# # 7. ROC Curves Visualization and Failure Mode Analysis

# %%
plt.figure(figsize=(10, 8))
y_prob_np = np.array(y_prob)
for i in range(len(classes)):
    fpr, tpr, _ = roc_curve(y_true, y_prob_np[:, i], pos_label=i)
    plt.plot(fpr, tpr, label=f'ROC curve of {classes[i]}')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves (10:90 Split)')
plt.legend()
plt.show()
