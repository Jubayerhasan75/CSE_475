# %% [markdown]
# # 1. Environment Setup and Library Imports

# %%
# !pip install thop -q

import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from thop import profile
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, roc_auc_score, roc_curve

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
classes = ['AD', 'CN', 'MCI']
label_map = {cls: i for i, cls in enumerate(classes)}

# %% [markdown]
# # 2. Dataset Loading and Stratified Splitting (60:40 Ratio

# %%
base_path = '/kaggle/input/datasets/jubayerhasan755/notebook1-dataset/alzheimer'
all_paths = []
all_labels = []

for split_folder in ['train', 'test']:
    for cls in classes:
        folder_path = os.path.join(base_path, split_folder, cls)
        if os.path.exists(folder_path):
            for img in os.listdir(folder_path):
                if img.lower().endswith(('.png', '.jpg', '.jpeg')):
                    all_paths.append(os.path.join(folder_path, img))
                    all_labels.append(label_map[cls])

train_files, test_files, train_labels, test_labels = train_test_split(
    all_paths, all_labels, train_size=0.6, stratify=all_labels, random_state=42
)

t_files, v_files, t_labels, v_labels = train_test_split(
    train_files, train_labels, test_size=0.1, stratify=train_labels, random_state=42
)

class AlzheimerDataset(Dataset):
    def __init__(self, paths, labels, transform=None):
        self.paths = paths
        self.labels = labels
        self.transform = transform
    def __len__(self):
        return len(self.paths)
    def __getitem__(self, idx):
        img = Image.open(self.paths[idx]).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, self.labels[idx]

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_loader = DataLoader(AlzheimerDataset(t_files, t_labels, transform), batch_size=32, shuffle=True)
val_loader = DataLoader(AlzheimerDataset(v_files, v_labels, transform), batch_size=32)
test_loader = DataLoader(AlzheimerDataset(test_files, test_labels, transform), batch_size=32)

print(f"Total: {len(all_paths)} | Train: {len(t_files)} | Val: {len(v_files)} | Test: {len(test_files)}")
# Out:
# Total: 5154 | Train: 2782 | Val: 310 | Test: 2062

# %% [markdown]
# # 3. Computational Complexity: GFLOPs per Inference (Input Size: 224x224)

# %%
model = models.resnet50(weights='IMAGENET1K_V1')
model.fc = nn.Linear(model.fc.in_features, len(classes))
model = model.to(device)

dummy_in = torch.randn(1, 3, 224, 224).to(device)
macs, params = profile(model, inputs=(dummy_in, ), verbose=False)
gflops = (macs * 2) / 1e9

print(f"Fixed Input Size: 224x224 | GFLOPs: {gflops:.4f}")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 195MB/s]
# Fixed Input Size: 224x224 | GFLOPs: 8.2634

# %% [markdown]
# # 4. Model Training and Training Wall-clock Time Tracking

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

start_train = time.time()
for epoch in range(50):
    model.train()
    running_loss = 0.0
    for imgs, labs in train_loader:
        imgs, labs = imgs.to(device), labs.to(device)
        optimizer.zero_grad()
        loss = criterion(model(imgs), labs)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for imgs, labs in val_loader:
            imgs, labs = imgs.to(device), labs.to(device)
            val_loss += criterion(model(imgs), labs).item()
    
    print(f"Epoch [{epoch+1}/50] | Train Loss: {running_loss/len(train_loader):.4f} | Val Loss: {val_loss/len(val_loader):.4f}")

train_wall_time = time.time() - start_train
print(f"Total Training Wall-clock Time: {train_wall_time:.2f} s")
# Out:
# Epoch [1/50] | Train Loss: 0.3607 | Val Loss: 0.1431
# Epoch [2/50] | Train Loss: 0.0414 | Val Loss: 0.0385
# Epoch [3/50] | Train Loss: 0.0468 | Val Loss: 0.2126
# Epoch [4/50] | Train Loss: 0.0537 | Val Loss: 0.0557
# Epoch [5/50] | Train Loss: 0.0231 | Val Loss: 0.0343
# Epoch [6/50] | Train Loss: 0.0218 | Val Loss: 0.0554
# Epoch [7/50] | Train Loss: 0.0123 | Val Loss: 0.0275
# Epoch [8/50] | Train Loss: 0.0116 | Val Loss: 0.0246
# Epoch [9/50] | Train Loss: 0.0066 | Val Loss: 0.0058
# Epoch [10/50] | Train Loss: 0.0108 | Val Loss: 0.0415
# Epoch [11/50] | Train Loss: 0.0357 | Val Loss: 0.0704
# Epoch [12/50] | Train Loss: 0.0166 | Val Loss: 0.0599
# Epoch [13/50] | Train Loss: 0.0098 | Val Loss: 0.0455
# Epoch [14/50] | Train Loss: 0.0082 | Val Loss: 0.0197
# Epoch [15/50] | Train Loss: 0.0012 | Val Loss: 0.0064
# Epoch [16/50] | Train Loss: 0.0010 | Val Loss: 0.0105
# Epoch [17/50] | Train Loss: 0.0005 | Val Loss: 0.0067
# Epoch [18/50] | Train Loss: 0.0003 | Val Loss: 0.0066
# Epoch [19/50] | Train Loss: 0.0001 | Val Loss: 0.0052
# Epoch [20/50] | Train Loss: 0.0002 | Val Loss: 0.0081
# Epoch [21/50] | Train Loss: 0.0019 | Val Loss: 0.0168
# Epoch [22/50] | Train Loss: 0.0126 | Val Loss: 0.3393
# Epoch [23/50] | Train Loss: 0.0926 | Val Loss: 0.6052
# Epoch [24/50] | Train Loss: 0.0713 | Val Loss: 0.1194
# Epoch [25/50] | Train Loss: 0.0140 | Val Loss: 0.0177
# Epoch [26/50] | Train Loss: 0.0047 | Val Loss: 0.0105
# Epoch [27/50] | Train Loss: 0.0023 | Val Loss: 0.0031
# Epoch [28/50] | Train Loss: 0.0004 | Val Loss: 0.0017
# Epoch [29/50] | Train Loss: 0.0004 | Val Loss: 0.0037
# Epoch [30/50] | Train Loss: 0.0002 | Val Loss: 0.0036
# Epoch [31/50] | Train Loss: 0.0002 | Val Loss: 0.0024
# Epoch [32/50] | Train Loss: 0.0001 | Val Loss: 0.0031
# Epoch [33/50] | Train Loss: 0.0004 | Val Loss: 0.0019
# Epoch [34/50] | Train Loss: 0.0001 | Val Loss: 0.0020
# Epoch [35/50] | Train Loss: 0.0003 | Val Loss: 0.0021
# Epoch [36/50] | Train Loss: 0.0001 | Val Loss: 0.0020
# Epoch [37/50] | Train Loss: 0.0001 | Val Loss: 0.0014
# Epoch [38/50] | Train Loss: 0.0001 | Val Loss: 0.0018
# Epoch [39/50] | Train Loss: 0.0001 | Val Loss: 0.0013
# Epoch [40/50] | Train Loss: 0.0002 | Val Loss: 0.0010
# Epoch [41/50] | Train Loss: 0.0001 | Val Loss: 0.0008
# Epoch [42/50] | Train Loss: 0.0001 | Val Loss: 0.0007
# Epoch [43/50] | Train Loss: 0.0001 | Val Loss: 0.0017
# Epoch [44/50] | Train Loss: 0.0004 | Val Loss: 0.0013
# Epoch [45/50] | Train Loss: 0.0001 | Val Loss: 0.0008
# Epoch [46/50] | Train Loss: 0.0001 | Val Loss: 0.0012
# Epoch [47/50] | Train Loss: 0.0001 | Val Loss: 0.0007
# Epoch [48/50] | Train Loss: 0.0001 | Val Loss: 0.0007
# Epoch [49/50] | Train Loss: 0.0001 | Val Loss: 0.0006
# Epoch [50/50] | Train Loss: 0.0000 | Val Loss: 0.0005
# Total Training Wall-clock Time: 2032.94 s

# %% [markdown]
# # 5. Global Performance Metrics and Testing Wall-clock Time

# %%
model.eval()
y_true, y_pred, y_prob = [], [], []
start_test = time.time()
with torch.no_grad():
    for imgs, labs in test_loader:
        imgs, labs = imgs.to(device), labs.to(device)
        out = model(imgs)
        y_prob.extend(torch.softmax(out, dim=1).cpu().numpy())
        y_pred.extend(torch.argmax(out, dim=1).cpu().numpy())
        y_true.extend(labs.cpu().numpy())
test_wall_time = time.time() - start_test

acc = accuracy_score(y_true, y_pred)
p, r, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')
auc = roc_auc_score(y_true, y_prob, multi_class='ovr')

print(f"Accuracy: {acc:.4f}\nPrecision: {p:.4f}\nRecall: {r:.4f}\nF1: {f1:.4f}\nAUC: {auc:.4f}\nTesting Wall-clock Time: {test_wall_time:.2f}s")
# Out:
# Accuracy: 0.9971
# Precision: 0.9971
# Recall: 0.9971
# F1: 0.9971
# AUC: 1.0000
# Testing Wall-clock Time: 26.54s

# %% [markdown]
# # 6. Per-class Accuracy and Confusion Matrix Analysis

# %%
cm = confusion_matrix(y_true, y_pred)
class_acc = cm.diagonal() / cm.sum(axis=1)

for i, cls in enumerate(classes):
    print(f"Accuracy for {cls}: {class_acc[i]:.4f}")

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.title('Confusion Matrix (60:40 Split)')
plt.show()
# Out:
# Accuracy for AD: 1.0000
# Accuracy for CN: 0.9913
# Accuracy for MCI: 0.9990

# %% [markdown]
# # 7. ROC Curves Visualization and Failure Mode Analysis

# %%
plt.figure(figsize=(10, 8))
y_prob_np = np.array(y_prob)
for i in range(len(classes)):
    fpr, tpr, _ = roc_curve(y_true, y_prob_np[:, i], pos_label=i)
    plt.plot(fpr, tpr, label=f'ROC {classes[i]}')

plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curves (60:40 Split)')
plt.legend()
plt.show()
