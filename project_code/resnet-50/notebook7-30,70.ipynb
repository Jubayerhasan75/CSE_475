# %% [markdown]
# # 1. Environment Setup and Library Imports

# %%
# !pip install thop -q

import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from thop import profile
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, roc_auc_score, roc_curve

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
classes = ['AD', 'CN', 'MCI']
label_map = {cls: i for i, cls in enumerate(classes)}

# %% [markdown]
# # 2. Dataset Loading and Stratified Splitting (30:70 Ratio)

# %%
base_path = '/kaggle/input/datasets/jubayerhasan755/notebook1-dataset/alzheimer'
all_paths = []
all_labels = []

for split_folder in ['train', 'test']:
    for cls in classes:
        folder_path = os.path.join(base_path, split_folder, cls)
        if os.path.exists(folder_path):
            for img in os.listdir(folder_path):
                if img.lower().endswith(('.png', '.jpg', '.jpeg')):
                    all_paths.append(os.path.join(folder_path, img))
                    all_labels.append(label_map[cls])

train_files, test_files, train_labels, test_labels = train_test_split(
    all_paths, all_labels, train_size=0.3, stratify=all_labels, random_state=42
)

t_files, v_files, t_labels, v_labels = train_test_split(
    train_files, train_labels, test_size=0.1, stratify=train_labels, random_state=42
)

class AlzheimerDataset(Dataset):
    def __init__(self, paths, labels, transform=None):
        self.paths = paths
        self.labels = labels
        self.transform = transform
    def __len__(self):
        return len(self.paths)
    def __getitem__(self, idx):
        img = Image.open(self.paths[idx]).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, self.labels[idx]

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_loader = DataLoader(AlzheimerDataset(t_files, t_labels, transform), batch_size=32, shuffle=True)
val_loader = DataLoader(AlzheimerDataset(v_files, v_labels, transform), batch_size=32)
test_loader = DataLoader(AlzheimerDataset(test_files, test_labels, transform), batch_size=32)

print(f"Total Images: {len(all_paths)}")
print(f"Training: {len(t_files)}, Validation: {len(v_files)}, Testing: {len(test_files)}")
# Out:
# Total Images: 5154
# Training: 1391, Validation: 155, Testing: 3608

# %% [markdown]
# # 3. Computational Complexity: GFLOPs per Inference (Input Size: 224x224)

# %%
model = models.resnet50(weights='IMAGENET1K_V1')
model.fc = nn.Linear(model.fc.in_features, len(classes))
model = model.to(device)

dummy_in = torch.randn(1, 3, 224, 224).to(device)
macs, params = profile(model, inputs=(dummy_in, ), verbose=False)
gflops = (macs * 2) / 1e9

print(f"Fixed Input Size: 224x224")
print(f"GFLOPs: {gflops:.4f}")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 175MB/s]
# Fixed Input Size: 224x224
# GFLOPs: 8.2634

# %% [markdown]
# # 4. Model Training and Training Wall-clock Time Tracking

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

start_train = time.time()
for epoch in range(50):
    model.train()
    running_loss = 0.0
    for imgs, labs in train_loader:
        imgs, labs = imgs.to(device), labs.to(device)
        optimizer.zero_grad()
        loss = criterion(model(imgs), labs)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for imgs, labs in val_loader:
            imgs, labs = imgs.to(device), labs.to(device)
            val_loss += criterion(model(imgs), labs).item()
    
    print(f"Epoch [{epoch+1}/50] | Train Loss: {running_loss/len(train_loader):.4f} | Val Loss: {val_loss/len(val_loader):.4f}")

train_wall_time = time.time() - start_train
print(f"Total Training Time: {train_wall_time:.2f} s")
# Out:
# Epoch [1/50] | Train Loss: 0.6123 | Val Loss: 0.4853
# Epoch [2/50] | Train Loss: 0.0953 | Val Loss: 0.1735
# Epoch [3/50] | Train Loss: 0.0756 | Val Loss: 0.0861
# Epoch [4/50] | Train Loss: 0.0402 | Val Loss: 0.1582
# Epoch [5/50] | Train Loss: 0.0163 | Val Loss: 0.1063
# Epoch [6/50] | Train Loss: 0.0068 | Val Loss: 0.0930
# Epoch [7/50] | Train Loss: 0.0039 | Val Loss: 0.0522
# Epoch [8/50] | Train Loss: 0.0018 | Val Loss: 0.0489
# Epoch [9/50] | Train Loss: 0.0014 | Val Loss: 0.0375
# Epoch [10/50] | Train Loss: 0.0009 | Val Loss: 0.0595
# Epoch [11/50] | Train Loss: 0.0012 | Val Loss: 0.0529
# Epoch [12/50] | Train Loss: 0.0012 | Val Loss: 0.1320
# Epoch [13/50] | Train Loss: 0.0141 | Val Loss: 0.3404
# Epoch [14/50] | Train Loss: 0.1165 | Val Loss: 1.3511
# Epoch [15/50] | Train Loss: 0.1278 | Val Loss: 0.6206
# Epoch [16/50] | Train Loss: 0.0527 | Val Loss: 0.1381
# Epoch [17/50] | Train Loss: 0.0479 | Val Loss: 0.0751
# Epoch [18/50] | Train Loss: 0.0193 | Val Loss: 0.1089
# Epoch [19/50] | Train Loss: 0.0082 | Val Loss: 0.1660
# Epoch [20/50] | Train Loss: 0.0043 | Val Loss: 0.0883
# Epoch [21/50] | Train Loss: 0.0016 | Val Loss: 0.0768
# Epoch [22/50] | Train Loss: 0.0013 | Val Loss: 0.0681
# Epoch [23/50] | Train Loss: 0.0006 | Val Loss: 0.0647
# Epoch [24/50] | Train Loss: 0.0010 | Val Loss: 0.0510
# Epoch [25/50] | Train Loss: 0.0005 | Val Loss: 0.0640
# Epoch [26/50] | Train Loss: 0.0003 | Val Loss: 0.0725
# Epoch [27/50] | Train Loss: 0.0003 | Val Loss: 0.0643
# Epoch [28/50] | Train Loss: 0.0006 | Val Loss: 0.0521
# Epoch [29/50] | Train Loss: 0.0005 | Val Loss: 0.0748
# Epoch [30/50] | Train Loss: 0.0003 | Val Loss: 0.0583
# Epoch [31/50] | Train Loss: 0.0002 | Val Loss: 0.0716
# Epoch [32/50] | Train Loss: 0.0007 | Val Loss: 0.0540
# Epoch [33/50] | Train Loss: 0.0014 | Val Loss: 0.0460
# Epoch [34/50] | Train Loss: 0.0014 | Val Loss: 0.0384
# Epoch [35/50] | Train Loss: 0.0007 | Val Loss: 0.0179
# Epoch [36/50] | Train Loss: 0.0007 | Val Loss: 0.0300
# Epoch [37/50] | Train Loss: 0.0005 | Val Loss: 0.0300
# Epoch [38/50] | Train Loss: 0.0004 | Val Loss: 0.0526
# Epoch [39/50] | Train Loss: 0.0005 | Val Loss: 0.0287
# Epoch [40/50] | Train Loss: 0.0004 | Val Loss: 0.0222
# Epoch [41/50] | Train Loss: 0.0002 | Val Loss: 0.0226
# Epoch [42/50] | Train Loss: 0.0003 | Val Loss: 0.0396
# Epoch [43/50] | Train Loss: 0.0002 | Val Loss: 0.0480
# Epoch [44/50] | Train Loss: 0.0002 | Val Loss: 0.0418
# Epoch [45/50] | Train Loss: 0.0001 | Val Loss: 0.0506
# Epoch [46/50] | Train Loss: 0.0001 | Val Loss: 0.0476
# Epoch [47/50] | Train Loss: 0.0002 | Val Loss: 0.0406
# Epoch [48/50] | Train Loss: 0.0002 | Val Loss: 0.0435
# Epoch [49/50] | Train Loss: 0.0020 | Val Loss: 0.0885
# Epoch [50/50] | Train Loss: 0.0162 | Val Loss: 0.4638
# Total Training Time: 972.72 s

# %% [markdown]
# # 5. Global Performance Metrics and Testing Wall-clock Time

# %%
model.eval()
y_true, y_pred, y_prob = [], [], []
start_test = time.time()
with torch.no_grad():
    for imgs, labs in test_loader:
        imgs, labs = imgs.to(device), labs.to(device)
        out = model(imgs)
        y_prob.extend(torch.softmax(out, dim=1).cpu().numpy())
        y_pred.extend(torch.argmax(out, dim=1).cpu().numpy())
        y_true.extend(labs.cpu().numpy())
test_wall_time = time.time() - start_test

acc = accuracy_score(y_true, y_pred)
p, r, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')
auc = roc_auc_score(y_true, y_prob, multi_class='ovr')

print(f"Accuracy: {acc:.4f}")
print(f"Precision: {p:.4f}")
print(f"Recall: {r:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"ROC-AUC: {auc:.4f}")
print(f"Testing Wall-clock Time: {test_wall_time:.2f} s")
# Out:
# Accuracy: 0.8672
# Precision: 0.8775
# Recall: 0.8672
# F1-score: 0.8553
# ROC-AUC: 0.9713
# Testing Wall-clock Time: 40.70 s

# %% [markdown]
# # 6. Per-class Accuracy and Confusion Matrix Analysis

# %%
cm = confusion_matrix(y_true, y_pred)
per_class_acc = cm.diagonal() / cm.sum(axis=1)

for i, cls in enumerate(classes):
    print(f"Accuracy for {cls}: {per_class_acc[i]:.4f}")

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix (30:70 Split)')
plt.show()
# Out:
# Accuracy for AD: 0.5095
# Accuracy for CN: 0.9524
# Accuracy for MCI: 0.9752

# %% [markdown]
# # 7. ROC Curves Visualization and Failure Mode Analysis

# %%
plt.figure(figsize=(10, 8))
y_prob_np = np.array(y_prob)
for i in range(len(classes)):
    fpr, tpr, _ = roc_curve(y_true, y_prob_np[:, i], pos_label=i)
    plt.plot(fpr, tpr, label=f'ROC curve of {classes[i]}')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves (30:70 Split)')
plt.legend()
plt.show()
