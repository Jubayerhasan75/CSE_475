# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve
)
from sklearn.preprocessing import label_binarize
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# %%
SPLIT_RATIO = 0.9   # change this in each notebook
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 50

# %%
import os
train_path = "/kaggle/input/datasets/redwanahmed2025/alzheimer-dataset/Alzheimer Dataset/train"
test_path  = "/kaggle/input/datasets/redwanahmed2025/alzheimer-dataset/Alzheimer Dataset/test"

all_images = []
all_labels = []

for base_path in [train_path, test_path]:
    for class_name in os.listdir(base_path):
        class_path = os.path.join(base_path, class_name)
        for img in os.listdir(class_path):
            all_images.append(os.path.join(class_path, img))
            all_labels.append(class_name)

df = pd.DataFrame({
    "filepath": all_images,
    "label": all_labels
})

print("Total samples:", len(df))
print(df["label"].value_counts())
# Out:
# Total samples: 5154
# label
# MCI    2590
# CN     1440
# AD     1124
# Name: count, dtype: int64

# %%
train_df, test_df = train_test_split(
    df,
    train_size=SPLIT_RATIO,
    stratify=df["label"],
    random_state=42
)

# Now create validation (10% of training)
train_df, val_df = train_test_split(
    train_df,
    test_size=0.10,
    stratify=train_df["label"],
    random_state=42
)

print("Train:", len(train_df))
print("Val:", len(val_df))
print("Test:", len(test_df))
# Out:
# Train: 4174
# Val: 464
# Test: 516

# %%
AUTOTUNE = tf.data.AUTOTUNE

def load_image(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (IMG_SIZE, IMG_SIZE))
    img = preprocess_input(img)
    return img, label

def create_dataset(df):
    paths = df["filepath"].values
    labels = pd.Categorical(df["label"]).codes
    
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    ds = ds.map(load_image, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds

train_ds = create_dataset(train_df)
val_ds   = create_dataset(val_df)
test_ds  = create_dataset(test_df)

# %%
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_df["label"]),
    y=train_df["label"]
)

class_weights = dict(enumerate(class_weights))
print("Class Weights:", class_weights)
# Out:
# Class Weights: {0: np.float64(1.5289377289377288), 1: np.float64(1.1932532875929103), 2: np.float64(0.6631712742294249)}

# %%
base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False  # first stage

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.3),
    layers.Dense(3, activation="softmax")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │         3,843 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,261,827 (8.63 MB)
#  Trainable params: 3,843 (15.01 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
start_time = time.time()

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    class_weight=class_weights
)

training_time = time.time() - start_time
print("Training time (seconds):", training_time)
# Out:
# Epoch 1/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 25s 123ms/step - accuracy: 0.3081 - loss: 1.2984 - val_accuracy: 0.4073 - val_loss: 1.0803
# Epoch 2/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.3517 - loss: 1.1937 - val_accuracy: 0.4310 - val_loss: 1.0437
# Epoch 3/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.3918 - loss: 1.1434 - val_accuracy: 0.4763 - val_loss: 1.0118
# Epoch 4/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.4414 - loss: 1.0877 - val_accuracy: 0.5194 - val_loss: 0.9822
# Epoch 5/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.4438 - loss: 1.0682 - val_accuracy: 0.5259 - val_loss: 0.9639
# Epoch 6/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.4516 - loss: 1.0387 - val_accuracy: 0.5453 - val_loss: 0.9522
# Epoch 7/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.4846 - loss: 1.0185 - val_accuracy: 0.5625 - val_loss: 0.9209
# Epoch 8/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.4990 - loss: 1.0099 - val_accuracy: 0.5603 - val_loss: 0.9146
# Epoch 9/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.5231 - loss: 0.9665 - val_accuracy: 0.5668 - val_loss: 0.9014
# Epoch 10/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5153 - loss: 0.9634 - val_accuracy: 0.5905 - val_loss: 0.8908
# Epoch 11/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5365 - loss: 0.9537 - val_accuracy: 0.6056 - val_loss: 0.8761
# Epoch 12/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.5447 - loss: 0.9333 - val_accuracy: 0.6164 - val_loss: 0.8747
# Epoch 13/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5460 - loss: 0.9236 - val_accuracy: 0.6121 - val_loss: 0.8672
# Epoch 14/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.5634 - loss: 0.9118 - val_accuracy: 0.6207 - val_loss: 0.8537
# Epoch 15/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.5654 - loss: 0.8977 - val_accuracy: 0.6250 - val_loss: 0.8479
# Epoch 16/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.5805 - loss: 0.8674 - val_accuracy: 0.6401 - val_loss: 0.8414
# Epoch 17/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.5773 - loss: 0.8794 - val_accuracy: 0.6487 - val_loss: 0.8280
# Epoch 18/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.6078 - loss: 0.8615 - val_accuracy: 0.6616 - val_loss: 0.8236
# Epoch 19/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.6169 - loss: 0.8427 - val_accuracy: 0.6659 - val_loss: 0.8178
# Epoch 20/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.6084 - loss: 0.8392 - val_accuracy: 0.6616 - val_loss: 0.8144
# Epoch 21/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.6188 - loss: 0.8405 - val_accuracy: 0.6703 - val_loss: 0.8076
# Epoch 22/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.6177 - loss: 0.8324 - val_accuracy: 0.6530 - val_loss: 0.8111
# Epoch 23/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.6297 - loss: 0.8291 - val_accuracy: 0.6767 - val_loss: 0.7944
# Epoch 24/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - accuracy: 0.6339 - loss: 0.8108 - val_accuracy: 0.6767 - val_loss: 0.7865
# Epoch 25/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.6306 - loss: 0.8025 - val_accuracy: 0.6724 - val_loss: 0.7826
# Epoch 26/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.6225 - loss: 0.8135 - val_accuracy: 0.6703 - val_loss: 0.7864
# Epoch 27/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.6540 - loss: 0.7835 - val_accuracy: 0.6659 - val_loss: 0.7787
# Epoch 28/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6616 - loss: 0.7742 - val_accuracy: 0.6573 - val_loss: 0.7738
# Epoch 29/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6287 - loss: 0.7903 - val_accuracy: 0.6832 - val_loss: 0.7651
# Epoch 30/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6580 - loss: 0.7776 - val_accuracy: 0.6875 - val_loss: 0.7599
# Epoch 31/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6564 - loss: 0.7839 - val_accuracy: 0.6853 - val_loss: 0.7587
# Epoch 32/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6573 - loss: 0.7640 - val_accuracy: 0.6853 - val_loss: 0.7541
# Epoch 33/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6638 - loss: 0.7579 - val_accuracy: 0.6832 - val_loss: 0.7479
# Epoch 34/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6646 - loss: 0.7557 - val_accuracy: 0.6897 - val_loss: 0.7455
# Epoch 35/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6674 - loss: 0.7570 - val_accuracy: 0.7047 - val_loss: 0.7382
# Epoch 36/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6819 - loss: 0.7424 - val_accuracy: 0.6983 - val_loss: 0.7384
# Epoch 37/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.6755 - loss: 0.7514 - val_accuracy: 0.6853 - val_loss: 0.7353
# Epoch 38/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6963 - loss: 0.7285 - val_accuracy: 0.6983 - val_loss: 0.7278
# Epoch 39/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6844 - loss: 0.7344 - val_accuracy: 0.6940 - val_loss: 0.7290
# Epoch 40/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6688 - loss: 0.7383 - val_accuracy: 0.7004 - val_loss: 0.7229
# Epoch 41/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6890 - loss: 0.7333 - val_accuracy: 0.6918 - val_loss: 0.7224
# Epoch 42/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6791 - loss: 0.7322 - val_accuracy: 0.7004 - val_loss: 0.7189
# Epoch 43/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7026 - loss: 0.7139 - val_accuracy: 0.7026 - val_loss: 0.7161
# Epoch 44/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.6974 - loss: 0.7178 - val_accuracy: 0.7004 - val_loss: 0.7109
# Epoch 45/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6744 - loss: 0.7320 - val_accuracy: 0.7069 - val_loss: 0.7143
# Epoch 46/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6929 - loss: 0.7072 - val_accuracy: 0.7069 - val_loss: 0.7067
# Epoch 47/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6902 - loss: 0.7083 - val_accuracy: 0.7112 - val_loss: 0.7054
# Epoch 48/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6842 - loss: 0.7145 - val_accuracy: 0.7198 - val_loss: 0.7041
# Epoch 49/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7064 - loss: 0.6957 - val_accuracy: 0.7177 - val_loss: 0.6931
# Epoch 50/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7184 - loss: 0.6921 - val_accuracy: 0.7155 - val_loss: 0.6979
# Training time (seconds): 248.53863620758057

# %%
plt.figure()
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Accuracy Curve")
plt.legend(["Train", "Validation"])
plt.show()

plt.figure()
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Loss Curve")
plt.legend(["Train", "Validation"])
plt.show()

# %%
start_test = time.time()

y_true = []
y_pred = []
y_prob = []

for images, labels in test_ds:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))
    y_prob.extend(preds)

testing_time = time.time() - start_test

print("Testing time:", testing_time)
print("Accuracy:", accuracy_score(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Testing time: 10.773842811584473
# Accuracy: 0.7054263565891473
#               precision    recall  f1-score   support
#
#            0       0.65      0.74      0.69       113
#            1       0.60      0.77      0.67       144
#            2       0.84      0.65      0.74       259
#
#     accuracy                           0.71       516
#    macro avg       0.70      0.72      0.70       516
# weighted avg       0.73      0.71      0.71       516

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure()
sns.heatmap(cm, annot=True, fmt="d")
plt.title("Confusion Matrix")
plt.show()

# %%
y_true_bin = label_binarize(y_true, classes=[0,1,2])
auc = roc_auc_score(y_true_bin, y_prob, multi_class="ovr")

print("ROC-AUC:", auc)
# Out:
# ROC-AUC: 0.8854322466307254

# %%
concrete_func = tf.function(lambda x: model(x))
concrete_func = concrete_func.get_concrete_function(
    tf.TensorSpec([1, 224, 224, 3], tf.float32)
)

from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
frozen_func = convert_variables_to_constants_v2(concrete_func)
graph_def = frozen_func.graph.as_graph_def()

print("Approximate MobileNetV2 GFLOPs at 224x224 ≈ 0.3 GFLOPs")
# Out:
# I0000 00:00:1773087218.055550      55 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 2
# I0000 00:00:1773087218.055785      55 single_machine.cc:374] Starting new session
# I0000 00:00:1773087218.069686      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1773087218.071234      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Approximate MobileNetV2 GFLOPs at 224x224 ≈ 0.3 GFLOPs
